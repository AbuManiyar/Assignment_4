# %% [markdown]
# 1. What exactly is []?
# Ans: It is bracket and is used to creat a list. for ex:
# l = [2,3,7] and [] mean empty list
#
# 2. In a list of values stored in a variable called spam, how would you
# assign the value "hello" as the third value? (Assume [2, 4, 6, 8, 10] are
# in spam.)
# Ans: spam[2] = "hello"
#
#
# Let's pretend the spam includes the list ["a", "b", "c", "d"] for the next
# three queries.
# 3. What is the value of spam[int(int("3"*2)/11)]?
# Ans: the value of int(int("3"*2)/11) is 3 hence it will give fourth element
# "d"
#
# 4. What is the value of spam[-1]?
# Ans: It is last element "d"
#
# 5. What is the value of spam[:2]?
# Ans: ["a", "b"]
#
# Let's pretend bacon has the list [3.14, "cat," 11, "cat,"
# True] for the next three questions.
# 6. What is the value of bacon.index("cat")?
# Ans: It will give 1
#
# 7. How does bacon.append(99) change the look of the list value in bacon?
# Ans: It will become [3.14, "cat", 11, "cat", True, 99]
#
#
# 8. How does bacon.remove("cat") change the look of the list in
# bacon?
# Ans: It will now become [3.14, 11, "cat", True, 99]
#
# 9. What are the list concatenation and list replication operators?
# Ans: Operator for list concatenation is +
# while the operator for replication is *
#
# 10. What is difference between the list methods append() and insert()?
# Ans: append() will simply add the given element at last of the list
# whereas insert() will add the given element at the given position in that
# list.
#
# 11. What are the two methods for removing items from a list?
# Ans: Two methods are remove() and pop()
#
#
# 12. Describe how list values and string values are identical.
# Ans: The are identical because list contains sequence of elements whereas
# string contain sequence of characters. And again the elements of list can
# be accessed by there index similarly characters of a string can also be
# accessed by there index number.Both strings and lists have lengths a
# string's length is number of characters in the string and list's length is
# the number of items in the list. by using len(name_of_variable) it can be
# string or list.
#
# 13. What's the difference between tuples and lists?
# Ans: The basic difference is lists are mutable whereas tuple are immutable
# means the elements of the list can be altered where as the elements of the
# tuple cannot be altered. And list has [] brackets but a tuple has ()
# braces. The other difference include, lists consume more memory whereas
# tuple consumes less memory as compared to the list.
#
#
# 14. How do you type a tuple value that only contains the integer 42?
# Ans: t=(42,) here comma after 42 is essential else it will be treated as
# int type
#
# 15. How do you get a list value's tuple form? How do you get a tuple
# value's list form?
# Ans: By using the function tuple() and passing list as its parameter
# a tuple form of the given list can be doone.Similarly to get list form of
# tuple we can pass tuple as parameter to list() function.
#
# 16.  Variables that "contain" list values are not necessarily
# lists themselves. Instead, what do they contain?
# Ans: They also contain references to list the values.
#
# 17. How do you distinguish between copy.copy() and copy.deepcopy()?
# Ans: copy also known as shallow copy/creates only the outer shell or
# first layer of compound object whereas the deepcopy will entirely
# constructs a new compound object whose id is different. deep copy does
# this process recursively. That is the basic difference between the copy
# and deepcopy. while a compound list is copied, copy will only create new
# copound list whose elements of outer list will be copied but the inner
# list elements will remain the same it does not changes it. whereas in
# deepcopy even that will also change.
